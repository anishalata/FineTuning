# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0ed3b444513e> in <cell line: 2>()
#     681   {
#     682    "cell_type": "code",
# --> 683    "execution_count": null,
#     684    "metadata": {},
#     685    "outputs": [],
#
# NameError: name 'null' is not defined
