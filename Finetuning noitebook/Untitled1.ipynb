# %%
_Created the first image by getting a glb of the nittany lion statue and replacing that with a file created on 8th wall.
-Created a blue and white striped image on canva with the correct pixel dimensions as the 8th wall template I did
